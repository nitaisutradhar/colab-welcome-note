# %% [markdown]
# <a href="https://colab.research.google.com/github/nitaisutradhar/colab-welcome-note/blob/main/Welcome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Welcome Note**

# %%
print ("Welcome here.")
# Out:
# Welcome here.

# %%
print ("Hello! I am Nitai.")
# Out:
# Hello! I am Nitai.
